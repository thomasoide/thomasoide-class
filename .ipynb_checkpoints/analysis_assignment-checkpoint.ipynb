# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('campus_crime.csv')

# %%
data["total_count"] = data["murder"] + data["manslaughter"] + data["forcible"]\
  + data["nonforce"] + data["robbery"] + data["agg_aslt"] + data["burglary"]\
  + data['vehicle'] + data["arson"]

# %%
data.sort_values('murder', ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 133                          San Jose State University      60472       2
# 164                              University of Arizona      39236       1
# 219  Virginia Polytechnic Institute and State Unive...     371232       1
# 183                  University of Illinois at Chicago      84273       1
# 0                               American River College      95250       0
# 155                 The University of Texas at El Paso      22640       0
# 145                    Tarrant County College District     300372       0
# 146                                  Temple University     294840       0
# 147             Texas A & M University-College Station     100460       0
# 148                  Texas State University-San Marcos      68174       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 133             0         3         0        2        13        24       13
# ...

# %%
data.sort_values('burglary', ascending=False)[:15]
# Out:
#                                       instname  total_enr  murder  \
# 209                       University of Toledo      67830       0
# 169       University of California-Los Angeles      39271       0
# 206      University of South Carolina-Columbia      30721       0
# 116  Pennsylvania State University-Main Campus      45628       0
# 142                     Stony Brook University      23920       0
# 210                         University of Utah      31660       0
# 1                     Arizona State University     289016       0
# 69              Indiana University-Bloomington      42731       0
# 167             University of California-Davis      63464       0
# 91                   Michigan State University     191300       0
# 176              University of Colorado Denver      44990       0
# 182                      University of Houston     119460       0
# 162                      University at Buffalo      28849       0
# ...

# %% [markdown]
# To subset the data, I searched for each SEC school individually and used each school's ID. Not the most efficient way, but it got the job done.

# %%
data[data.instname == 'University of Missouri-Columbia']
# Out:
#                             instname  total_enr  murder  manslaughter  \
# 195  University of Missouri-Columbia      33762       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 195        11         0        1         8        10        1      1
#
#      total_count
# 195           32

# %%
data[data.instname == 'Texas A & M University-College Station']
# Out:
#                                    instname  total_enr  murder  manslaughter  \
# 147  Texas A & M University-College Station     100460       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 147         3         0        1         0        29        3      1
#
#      total_count
# 147           37

# %%
data[data.instname == 'University of Kentucky']
# Out:
#                    instname  total_enr  murder  manslaughter  forcible  \
# 187  University of Kentucky     163356       0             0         5
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 187         0        3         4        13       12      0           37

# %%
data[data.instname == 'University of Florida']
# Out:
#                   instname  total_enr  murder  manslaughter  forcible  \
# 179  University of Florida      99178       0             0        10
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 179         0        1         6        27       14      0           58

# %%
data[data.instname == 'University of South Carolina-Columbia']
# Out:
#                                   instname  total_enr  murder  manslaughter  \
# 206  University of South Carolina-Columbia      30721       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson  \
# 206         1         0        2         8       113       22      0
#
#      total_count
# 206          146

# %%
data[data.instname == 'The University of Alabama']
# Out:
#                       instname  total_enr  murder  manslaughter  forcible  \
# 151  The University of Alabama      63294       0             0         3
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 151         0        5         3        68        2      1           82

# %%
data[data.instname == 'Auburn University']
# Out:
#             instname  total_enr  murder  manslaughter  forcible  nonforce  \
# 3  Auburn University      25469       0             0         1         0
#
#    robbery  agg_aslt  burglary  vehicle  arson  total_count
# 3        2         0        22        3      0           28

# %%
data[data.instname == 'Louisiana State University and Agricultural & Mechanical College']
# Out:
#                                              instname  total_enr  murder  \
# 86  Louisiana State University and Agricultural & ...      29718       0
#
#     manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 86             0         2         0        9         9        47       10
#
#     arson  total_count
# 86      3           80

# %%
data[data.instname == 'Mississippi State University']
# Out:
#                         instname  total_enr  murder  manslaughter  forcible  \
# 93  Mississippi State University      40848       0             0         1
#
#     nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 93         0        0         1        56        2      1           61

# %%
data[data.instname == 'University of Georgia']
# Out:
#                   instname  total_enr  murder  manslaughter  forcible  \
# 180  University of Georgia      34816       0             0         5
#
#      nonforce  robbery  agg_aslt  burglary  vehicle  arson  total_count
# 180         0        1         2        53        5      3           69

# %%
sec = data.iloc[[180, 93, 86, 3, 151, 206, 179, 187, 147, 195]]

# %%
sec.sort_values('burglary', ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 206              University of South Carolina-Columbia      30721       0
# 151                          The University of Alabama      63294       0
# 93                        Mississippi State University      40848       0
# 180                              University of Georgia      34816       0
# 86   Louisiana State University and Agricultural & ...      29718       0
# 147             Texas A & M University-College Station     100460       0
# 179                              University of Florida      99178       0
# 3                                    Auburn University      25469       0
# 187                             University of Kentucky     163356       0
# 195                    University of Missouri-Columbia      33762       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 206             0         1         0        2         8       113       22
# ...

# %%
sec.sort_values('forcible', ascending=False)[:10]
# Out:
#                                               instname  total_enr  murder  \
# 195                    University of Missouri-Columbia      33762       0
# 179                              University of Florida      99178       0
# 180                              University of Georgia      34816       0
# 187                             University of Kentucky     163356       0
# 151                          The University of Alabama      63294       0
# 147             Texas A & M University-College Station     100460       0
# 86   Louisiana State University and Agricultural & ...      29718       0
# 93                        Mississippi State University      40848       0
# 3                                    Auburn University      25469       0
# 206              University of South Carolina-Columbia      30721       0
#
#      manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 195             0        11         0        1         8        10        1
# ...

# %%
g = sns.PairGrid(data)
g.map_offdiag(plt.scatter);

# %%
g = sns.FacetGrid(data, size=7)

g.map(plt.scatter, "total_enr", "burglary", alpha=.8)

# %% [markdown]
# ## Story Ideas
# 1. Mizzou has the least amount of recorded burglaries in among SEC schools in the dataset. Why is that?
# 2. Mizzou has the second-least amount of total crime among reported SEC schools. However, it has the highest amount of reported forcible rapes, which make up nearly a third of its total crimes.
# 3. What would make a college campus more or less susceptible to crime? The total amount of crime varies a lot among colleges.
